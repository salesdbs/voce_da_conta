# %%
#! /usr/bin/python3.4 k34
#apt-get update && apt-get install libpq-dev python-dev
#pip install 
import os
import json
import requests
import sqlalchemy
from pandas.io.json import json_normalize 
from pandas import DataFrame, concat, Series, get_dummies

# %%
#Colocar o endereço da pasta em que se encontra os JSON dos deputados.
path_dos_json = '/home/jovyan/workspace/compartilhamento/Repositorios/voce_da_conta/'
#path_dos_json = './json/'

# %%
pwd
# Out:
# '/home/jovyan/workspace/compartilhamento/Repositorios/voce_da_conta/py'

# %%
#PARTE DO BANCO

# Connect to database (Note: The package psychopg2 is required for Postgres to work with SQLAlchemy)
engine = sqlalchemy.create_engine("postgresql://postgres:Postgres2018!@postgresdocker/DBclass_awareness")
con = engine.connect()

# %%
lista_dos_json = os.listdir(path_dos_json)
#lista_dos_json = lista_dos_json[1:3]

# %%
minha_lista = []
lista_dos_json
# Out:
# ['2018-06-01@00listaTODOSDeputados.json',
#  '2018-07-01@00listaTODOSDeputados.json',
#  'PDI',
#  '.git',
#  '2018-11-01@00listaTODOSDeputados.json',
#  '2019-06-01@00listaTODOSDeputados.json',
#  'py',
#  '2018-08-01@00listaTODOSDeputados.json',
#  '2019-03-01@00listaTODOSDeputados.json',
#  'README.md',
#  '2018-01-01@00listaTODOSDeputados.json',
#  '2018-12-01@00listaTODOSDeputados.json',
#  '2019-11-01@00listaTODOSDeputados.json',
#  '2019-04-01@00listaTODOSDeputados.json',
#  '2019-12-01@00listaTODOSDeputados.json',
#  'PBI',
#  '2019-10-01@00listaTODOSDeputados.json',
#  '2018-05-01@00listaTODOSDeputados.json',
#  '2019-02-01@00listaTODOSDeputados.json',
#  '2019-07-01@00listaTODOSDeputados.json',
#  '2018-09-01@00listaTODOSDeputados.json',
#  '2019-01-01@00listaTODOSDeputados.json',
#  '2018-04-01@00listaTODOSDeputados.json',
#  '2018-03-01@00listaTODOSDeputados.json',
#  '2019-09-01@00listaTODOSDeputados.json',
#  '2019-05-01@00listaTODOSDeputados.json',
#  '.vscode',
#  '2019-08-01@00listaTODOSDeputados.json',
#  'datasets',
#  '2018-10-01@00listaTODOSDeputados.json',
#  '2018-02-01@00listaTODOSDeputados.json',
#  'material_da_radio']

# %%
for json_mensal_deputados in lista_dos_json:
    arquivo_json_ = '{path}{json}'.format(path=path_dos_json,json=json_mensal_deputados)
    dados = json.load(open(arquivo_json_))

    print(dados['dados'][0], dados['dados'][1], dados['dados'][540], sep='\n\n',end='\n\n====>\n')

    for id_deputado in range(0,len(dados['dados'])):
        dados['dados'][id_deputado].update({'data_periodo':arquivo_json_[69:79]})

    print(dados['dados'][0], dados['dados'][1], dados['dados'][540], sep='\n\n',end='\n\n====>\n')

    df = DataFrame(dados['dados'])
    minha_lista.append(df)
# Out:
# {'id': 204554, 'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204554', 'nome': 'ABÍLIO SANTANA', 'siglaPartido': 'PL', 'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906', 'siglaUf': 'BA', 'idLegislatura': 56, 'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204554.jpg', 'email': 'dep.abiliosantana@camara.leg.br'}
#
# {'id': 204521, 'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204521', 'nome': 'ABOU ANNI', 'siglaPartido': 'PSL', 'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837', 'siglaUf': 'SP', 'idLegislatura': 56, 'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204521.jpg', 'email': 'dep.abouanni@camara.leg.br'}
#
# {'id': 178889, 'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178889', 'nome': 'ZÉ CARLOS', 'siglaPartido': 'PT', 'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844', 'siglaUf': 'MA', 'idLegislatura': 56, 'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178889.jpg', 'email': 'dep.zecarlos@camara.leg.br'}
#
# ====>
# {'id': 204554, 'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204554', 'nome': 'ABÍLIO SANTANA', 'siglaPartido': 'PL', 'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906', 'siglaUf': 'BA', 'idLegislatura': 56, 'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204554.jpg', 'email': 'dep.abiliosantana@camara.leg.br', 'data_periodo': '18-06-01@0'}
#
# {'id': 204521, 'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204521', 'nome': 'ABOU ANNI', 'siglaPartido': 'PSL', 'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837', 'siglaUf': 'SP', 'idLegislatura': 56, 'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204521.jpg', 'email': 'dep.abouanni@camara.leg.br', 'data_periodo': '18-06-01@0'}
#
# {'id': 178889, 'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178889', 'nome': 'ZÉ CARLOS', 'siglaPartido': 'PT', 'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844', 'siglaUf': 'MA', 'idLegislatura': 56, 'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178889.jpg', 'email': 'dep.zecarlos@camara.leg.br', 'data_periodo': '18-06-01@0'}
#
# ====>
# {'id': 204554, 'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204554', 'nome': 'ABÍLIO SANTANA', 'siglaPartido': 'PL', 'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906', 'siglaUf': 'BA', 'idLegislatura': 56, 'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204554.jpg', 'email': 'dep.abiliosantana@camara.leg.br'}
#
# {'id': 204521, 'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204521', 'nome': 'ABOU ANNI', 'siglaPartido': 'PSL', 'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837', 'siglaUf': 'SP', 'idLegislatura': 56, 'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204521.jpg', 'email': 'dep.abouanni@camara.leg.br'}
#
# {'id': 178889, 'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178889', 'nome': 'ZÉ CARLOS', 'siglaPartido': 'PT', 'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844', 'siglaUf': 'MA', 'idLegislatura': 56, 'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178889.jpg', 'email': 'dep.zecarlos@camara.leg.br'}
#
# ====>
# {'id': 204554, 'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204554', 'nome': 'ABÍLIO SANTANA', 'siglaPartido': 'PL', 'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906', 'siglaUf': 'BA', 'idLegislatura': 56, 'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204554.jpg', 'email': 'dep.abiliosantana@camara.leg.br', 'data_periodo': '18-07-01@0'}
#
# {'id': 204521, 'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204521', 'nome': 'ABOU ANNI', 'siglaPartido': 'PSL', 'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36837', 'siglaUf': 'SP', 'idLegislatura': 56, 'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204521.jpg', 'email': 'dep.abouanni@camara.leg.br', 'data_periodo': '18-07-01@0'}
#
# {'id': 178889, 'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/178889', 'nome': 'ZÉ CARLOS', 'siglaPartido': 'PT', 'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36844', 'siglaUf': 'MA', 'idLegislatura': 56, 'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/178889.jpg', 'email': 'dep.zecarlos@camara.leg.br', 'data_periodo': '18-07-01@0'}
#
# ====>
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-18-98c1fe668676> in <module>
#       1 for json_mensal_deputados in lista_dos_json:
#       2     arquivo_json_ = '{path}{json}'.format(path=path_dos_json,json=json_mensal_deputados)
# ----> 3     dados = json.load(open(arquivo_json_))
#       4
#       5     print(dados['dados'][0], dados['dados'][1], dados['dados'][540], sep='\n\n',end='\n\n====>\n')
#
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/workspace/compartilhamento/Repositorios/voce_da_conta/PDI'

# %%
df3 = concat(minha_lista, ignore_index=False)

# %%
#PARTE DO BANCO
#table_name = 'deputados'
##df3.to_sql(table_name, con, if_exists='append',)
print(engine.table_names())
# Out:
# []

# %%
#df['id'].unique().tolist()
#df['id'].unique()
#ddd = {df['nome'].unique():df['id'].unique()}


#Linhas 0 até o 2 da coluna 0:
df3.iloc[0:5,3]
# Out:
# 0      PL
# 1     PSL
# 2    PROS
# 3    PSDB
# 4    NOVO
# Name: siglaPartido, dtype: object

# %%
len(df3.id.unique())
#df3.id.unique()[1:3]
# Out:
# 545

# %%
detalhe_deputados = []
for id in df3.id.unique():#df3.id.unique()[1:3]:
    print(id)
#Detalhe do deputado:
    request_detalhe = requests.get('https://dadosabertos.camara.leg.br/api/v2/deputados/{id!s}'.format(id=id))
    json_detalhe = json.loads(request_detalhe.text)
    df_detalhado = json_normalize(json_detalhe['dados'])
    detalhe_deputados.append(df_detalhado) 
#Solicitação de reembolso do deputado:
    #vai ser aqui....
# Out:
# 204554
# 204521
# 204379
# 204560
# 204528
# 121948
# 74646
# 160508
# 136811
# 178835
# 160527
# 204495
# 204549
# 178836
# 160559
# 204413
# 204545
# 204501
# 160511
# 178972
# 204571
# 204544
# 160545
# 204503
# 178833
# 204516
# 74057
# 178927
# 204353
# 204400
# 178937
# 178881
# 204356
# 178831
# 74471
# 204423
# 133439
# 178882
# 204515
# 73696
# 74212
# 160553
# 73433
# 141391
# 204414
# 160541
# 160600
# 159237
# 74090
# 74459
# 160665
# 204509
# 160512
# 69871
# 178975
# 73701
# 109429
# 141335
# 204358
# 178948
# 207176
# 204374
# 204388
# 141513
# 204561
# 204397
# 160538
# 74052
# 204551
# 160589
# 93083
# 178853
# 204352
# 204572
# 178829
# 178924
# 204487
# 204507
# 141401
# 204361
# 178962
# 178993
# 204460
# 74262
# 204426
# 141398
# 164360
# 204369
# 204499
# 204380
# 204370
# 178876
# 204488
# 141405
# 73441
# 204496
# 204504
# 205476
# 204490
# 141439
# 204476
# 204462
# 178928
# 204440
# 178939
# 74537
# 141408
# 204376
# 204378
# 204514
# 178963
# 135054
# 204355
# 141411
# 74467
# 74060
# 178916
# 204367
# 204454
# 204409
# 204459
# 160528
# 160552
# 116379
# 73891
# 205548
# 204511
# 204451
# 178908
# 204512
# 204569
# 164359
# 204542
# 160588
# 178929
# 160599
# 143632
# 160758
# 204518
# 212625
# 204481
# 204439
# 204450
# 204351
# 204412
# 81297
# 204434
# 178994
# 204562
# 141417
# 134812
# 204421
# 74655
# 204541
# 92346
# 204552
# 204500
# 178977
# 141421
# 141422
# 74075
# 204364
# 160532
# 204389
# 178854
# 198783
# 161550
# 207309
# 132504
# 204537
# 160575
# 160640
# 204482
# 178871
# 178953
# 211866
# 141428
# 68720
# 178969
# 141427
# 171623
# 204368
# 160587
# 66828
# 204477
# 72442
# 204398
# 204371
# 160666
# 204407
# 212504
# 141431
# 204445
# 92699
# 204427
# 204411
# 204354
# 160598
# 141434
# 191923
# 204447
# 204392
# 204510
# 204494
# 204393
# 74200
# 115746
# 160669
# 204473
# 204484
# 204527
# 178966
# 74374
# 204394
# 74383
# 204575
# 204491
# 74270
# 204570
# 204365
# 160673
# 178996
# 152605
# 204419
# 107283
# 74419
# 198197
# 204513
# 204531
# 160667
# 204442
# 73460
# 204408
# 204456
# 204465
# 204548
# 178964
# 178873
# 204373
# 178909
# 204444
# 73482
# 204539
# 178981
# 73772
# 178884
# 178959
# 141450
# 160674
# 204533
# 204564
# 204508
# 67138
# 204436
# 73531
# 74848
# 108338
# 160672
# 74273
# 160570
# 178839
# 204435
# 178842
# 160531
# 74366
# 141458
# 178970
# 204429
# 141459
# 112437
# 204576
# 178910
# 204468
# 204546
# 205550
# 178857
# 141464
# 141470
# 204386
# 204472
# 204391
# 160619
# 74079
# 204555
# 74554
# 209189
# 74141
# 204563
# 204474
# 204420
# 74317
# 204372
# 73586
# 204457
# 204520
# 204502
# 204497
# 204574
# 204550
# 178886
# 204536
# 151208
# 98057
# 160534
# 178832
# 204375
# 204359
# 204547
# 74156
# 74299
# 92102
# 139285
# 74585
# 204405
# 204382
# 196358
# 204523
# 204404
# 178879
# 74478
# 178931
# 178954
# 204381
# 160510
# 204410
# 204448
# 160645
# 204485
# 204543
# 178982
# 204455
# 162332
# 204526
# 74784
# 204418
# 178866
# 166402
# 204458
# 204469
# 204471
# 212749
# 156190
# 179000
# 146788
# 205863
# 204433
# 76874
# 133810
# 204558
# 204556
# 178983
# 179001
# 81055
# 204452
# 150418
# 204522
# 160535
# 204431
# 204506
# 178943
# 159238
# 204430
# 171619
# 74398
# 204540
# 178956
# 204428
# 204432
# 74158
# 178858
# 204403
# 204566
# 178843
# 75431
# 204486
# 74749
# 141508
# 188097
# 178984
# 178985
# 154178
# 178895
# 178997
# 204453
# 204449
# 74571
# 204415
# 146307
# 178896
# 204384
# 204479
# 74352
# 178986
# 194260
# 66179
# 74159
# 204498
# 74399
# 178987
# 204363
# 73692
# 204422
# 204475
# 204441
# 204573
# 160556
# 74319
# 160642
# 204553
# 205535
# 74160
# 204377
# 171617
# 141516
# 178860
# 204538
# 193726
# 160517
# 160558
# 204461
# 204492
# 74574
# 141518
# 74400
# 133968
# 141488
# 90201
# 178912
# 122974
# 204395
# 122158
# 160604
# 204406
# 73943
# 204524
# 204529
# 73486
# 160601
# 204390
# 204383
# 204446
# 204565
# 160639
# 160641
# 204467
# 178951
# 204567
# 141523
# 74161
# 205865
# 178925
# 178989
# 73801
# 73788
# 204362
# 160655
# 211649
# 178920
# 204489
# 152610
# 160653
# 74305
# 204530
# 204366
# 141531
# 74693
# 204480
# 160651
# 178930
# 178861
# 122466
# 204525
# 178945
# 204357
# 73466
# 74371
# 178887
# 73604
# 160635
# 204535
# 178990
# 204416
# 160621
# 90842
# 204387
# 204399
# 178921
# 73808
# 178933
# 204438
# 178874
# 204437
# 178961
# 204557
# 74356
# 204360
# 204425
# 168175
# 178946
# 178947
# 92776
# 177282
# 204534
# 178922
# 204464
# 206231
# 178901
# 204466
# 143084
# 204519
# 160976
# 197438
# 178934
# 157130
# 178863
# 195866
# 204385
# 160610
# 141552
# 74376
# 141553
# 204505
# 204396
# 74283
# 137070
# 204483
# 141555
# 204478
# 160591
# 204532
# 179587
# 178992
# 204443
# 160569
# 178952
# 160518
# 74043
# 74044
# 204463
# 74439
# 178889
# 204559
# 160632
# 204517
# 160592

# %%
detalhe_deputados
# Out:
# [       id                                                uri  \
#  0  204554  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                        nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  JOSE ABILIO SILVA DE SANTANA  36607606504    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1965-02-13            None           BA  ...             ABÍLIO SANTANA
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        531                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        531                           5
#
#    ultimoStatus.gabinete.telefone      ultimoStatus.gabinete.email  \
#  0                      3215-5531  dep.abiliosantana@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204521  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                  nomeCivil          cpf sexo urlWebsite  \
#  0  PAULO SERGIO ABOU ANNI  08496582841    M       None
#
#                                            redeSocial dataNascimento  \
#  0  [https://www.facebook.com/abou.anni.7, https:/...     1966-11-06
#
#    dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0            None           SP  ...                  ABOU ANNI
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        339                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        339                           3
#
#    ultimoStatus.gabinete.telefone ultimoStatus.gabinete.email  \
#  0                      3215-5339  dep.abouanni@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204379  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                        nomeCivil          cpf sexo urlWebsite  \
#  0  ACÁCIO DA SILVA FAVACHO NETO  74287028287    M       None
#
#                                            redeSocial dataNascimento  \
#  0  [acaciofavacho, deputadofederalacaciofavacho, ...     1983-09-28
#
#    dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0            None           AP  ...             ACÁCIO FAVACHO
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        284                             3
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        284                        None
#
#    ultimoStatus.gabinete.telefone      ultimoStatus.gabinete.email  \
#  0                      3215-5284  dep.acaciofavacho@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204560  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                       nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ADOLFO VIANA DE CASTRO NETO  80123848504    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1981-02-02            None           BA  ...               ADOLFO VIANA
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        911                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        911                           9
#
#    ultimoStatus.gabinete.telefone    ultimoStatus.gabinete.email  \
#  0                      3215-5911  dep.adolfoviana@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204528  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                  nomeCivil          cpf sexo urlWebsite  \
#  0  ADRIANA MIGUEL VENTURA  12519851813    F       None
#
#                                            redeSocial dataNascimento  \
#  0  [adrianasounovo, adrianasounovo, adrianam_vent...     1969-03-06
#
#    dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0            None           SP  ...            ADRIANA VENTURA
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        802                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        802                           8
#
#    ultimoStatus.gabinete.telefone       ultimoStatus.gabinete.email  \
#  0                      3215-5802  dep.adrianaventura@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  121948  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                  nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ADRIANO ANTÔNIO AVELAR  50746553153    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1969-09-06            None           GO  ...           ADRIANO DO BALDY
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        419                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        419                           4
#
#    ultimoStatus.gabinete.telefone       ultimoStatus.gabinete.email  \
#  0                      3215-5419  dep.adrianodobaldy@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#        id                                                uri  \
#  0  74646  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  AÉCIO NEVES DA CUNHA  66728983791    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1960-03-10            None           MG  ...                AÉCIO NEVES
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                         20                             x
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                         20                        None
#
#    ultimoStatus.gabinete.telefone   ultimoStatus.gabinete.email  \
#  0                      3215-5964  dep.aecioneves@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  160508  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                    nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  AFONSO BANDEIRA FLORENCE  17734150500    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1960-10-15            None           BA  ...            AFONSO FLORENCE
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        305                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        305                           3
#
#    ultimoStatus.gabinete.telefone       ultimoStatus.gabinete.email  \
#  0                      3215-5305  dep.afonsoflorence@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  136811  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                   nomeCivil          cpf sexo urlWebsite  \
#  0  JOSÉ ALFONSO EBERT HAMM  37040642034    M       None
#
#                      redeSocial dataNascimento dataFalecimento ufNascimento  \
#  0  [depafonsohamm, afonsohamm]     1962-04-25            None           RS
#
#     ... ultimoStatus.nomeEleitoral ultimoStatus.gabinete.nome  \
#  0  ...                AFONSO HAMM                        604
#
#     ultimoStatus.gabinete.predio ultimoStatus.gabinete.sala  \
#  0                             4                        604
#
#    ultimoStatus.gabinete.andar ultimoStatus.gabinete.telefone  \
#  0                           6                      3215-5604
#
#      ultimoStatus.gabinete.email ultimoStatus.situacao  \
#  0  dep.afonsohamm@camara.leg.br             Exercício
#
#     ultimoStatus.condicaoEleitoral ultimoStatus.descricaoStatus
#  0                         Titular                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  178835  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                   nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  AFONSO ANTUNES DA MOTTA  10777296004    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1950-01-08            None           RS  ...               AFONSO MOTTA
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        528                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        528                           5
#
#    ultimoStatus.gabinete.telefone    ultimoStatus.gabinete.email  \
#  0                      3215-5528  dep.afonsomotta@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  160527  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                            nomeCivil          cpf sexo urlWebsite  \
#  0  AGUINALDO VELLOSO BORGES RIBEIRO  51921146400    M       None
#
#                                            redeSocial dataNascimento  \
#  0  [depaguinaldoribeiro, depaguinaldoribeiro, dep...     1969-02-13
#
#    dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0            None           PB  ...          AGUINALDO RIBEIRO
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        735                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        735                           7
#
#    ultimoStatus.gabinete.telefone         ultimoStatus.gabinete.email  \
#  0                      3215-5735  dep.aguinaldoribeiro@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204495  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#               nomeCivil          cpf sexo urlWebsite redeSocial dataNascimento  \
#  0  AIRTON LUIZ FALEIRO  18836178200    M       None         []     1959-03-16
#
#    dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0            None           RS  ...             AIRTON FALEIRO
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        327                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        327                           3
#
#    ultimoStatus.gabinete.telefone      ultimoStatus.gabinete.email  \
#  0                      3215-5327  dep.airtonfaleiro@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204549  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                           nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ANTONIO JOSE AGUIAR ALBUQUERQUE  97506060353    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1983-09-26            None           CE  ...             AJ ALBUQUERQUE
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        708                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        708                           7
#
#    ultimoStatus.gabinete.telefone      ultimoStatus.gabinete.email  \
#  0                      3215-5708  dep.ajalbuquerque@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  178836  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#             nomeCivil          cpf sexo urlWebsite  \
#  0  ALAN RICK MIRANDA  44726570234    M       None
#
#                        redeSocial dataNascimento dataFalecimento ufNascimento  \
#  0  [deputadoalanrick, alanrickm]     1976-10-23            None           AC
#
#     ... ultimoStatus.nomeEleitoral ultimoStatus.gabinete.nome  \
#  0  ...                  ALAN RICK                        650
#
#     ultimoStatus.gabinete.predio ultimoStatus.gabinete.sala  \
#  0                             4                        650
#
#    ultimoStatus.gabinete.andar ultimoStatus.gabinete.telefone  \
#  0                           6                      3215-5650
#
#    ultimoStatus.gabinete.email ultimoStatus.situacao  \
#  0  dep.alanrick@camara.leg.br             Exercício
#
#     ultimoStatus.condicaoEleitoral ultimoStatus.descricaoStatus
#  0                         Titular                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  160559  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                  nomeCivil          cpf sexo urlWebsite  \
#  0  ALCEU MOREIRA DA SILVA  17968496004    M       None
#
#                             redeSocial dataNascimento dataFalecimento  \
#  0  [http://twitter.com/alceu_moreira]     1954-06-04            None
#
#    ufNascimento  ... ultimoStatus.nomeEleitoral ultimoStatus.gabinete.nome  \
#  0           RS  ...              ALCEU MOREIRA                        238
#
#     ultimoStatus.gabinete.predio ultimoStatus.gabinete.sala  \
#  0                             4                        238
#
#    ultimoStatus.gabinete.andar ultimoStatus.gabinete.telefone  \
#  0                           2                      3215-5238
#
#        ultimoStatus.gabinete.email ultimoStatus.situacao  \
#  0  dep.alceumoreira@camara.leg.br             Exercício
#
#     ultimoStatus.condicaoEleitoral ultimoStatus.descricaoStatus
#  0                         Titular                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204413  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                   nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ALCIDES RODRIGUES FILHO  13620983100    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1950-10-08            None           GO  ...          ALCIDES RODRIGUES
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        332                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        332                           3
#
#    ultimoStatus.gabinete.telefone         ultimoStatus.gabinete.email  \
#  0                      3215-5332  dep.alcidesrodrigues@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204545  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#               nomeCivil          cpf sexo urlWebsite redeSocial dataNascimento  \
#  0  ALESSANDRA DA SILVA  79875564915    F       None         []     1974-07-04
#
#    dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0            None           RJ  ...                  ALÊ SILVA
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        462                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        462                           4
#
#    ultimoStatus.gabinete.telefone ultimoStatus.gabinete.email  \
#  0                      3215-5462  dep.alesilva@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204501  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                 nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ALENCAR SANTANA BRAGA  05544839808    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1976-03-14            None           SP  ...      ALENCAR SANTANA BRAGA
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        239                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        239                           2
#
#    ultimoStatus.gabinete.telefone            ultimoStatus.gabinete.email  \
#  0                      3215-5239  dep.alencarsantanabraga@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  160511  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                     nomeCivil          cpf sexo urlWebsite  \
#  0  ALESSANDRO LUCCIOLA MOLON  01416576770    M       None
#
#                                            redeSocial dataNascimento  \
#  0  [http://www.twitter.com/alessandromolon, http:...     1971-10-28
#
#    dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0            None           MG  ...           ALESSANDRO MOLON
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        304                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        304                           3
#
#    ultimoStatus.gabinete.telefone        ultimoStatus.gabinete.email  \
#  0                      3215-5304  dep.alessandromolon@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  178972  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                 nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ALEX SPINELLI MANENTE  26838194805    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1979-08-22            None           SP  ...               ALEX MANENTE
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        205                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        205                           2
#
#    ultimoStatus.gabinete.telefone    ultimoStatus.gabinete.email  \
#  0                      3215-5205  dep.alexmanente@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204571  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                    nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ALEX MARCO SANTANA SOUSA  64682420534    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1972-06-22            None           BA  ...               ALEX SANTANA
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        541                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        541                           5
#
#    ultimoStatus.gabinete.telefone    ultimoStatus.gabinete.email  \
#  0                      3215-5541  dep.alexsantana@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204544  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                      nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ALEXANDRE FROTA DE ANDRADE  75199270753    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1963-10-14            None           RJ  ...            ALEXANDRE FROTA
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        216                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        216                           2
#
#    ultimoStatus.gabinete.telefone       ultimoStatus.gabinete.email  \
#  0                      3215-5216  dep.alexandrefrota@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  160545  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                    nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ALEXANDRE LEITE DA SILVA  22970812860    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1989-04-18            None           SP  ...            ALEXANDRE LEITE
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        841                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        841                           8
#
#    ultimoStatus.gabinete.telefone       ultimoStatus.gabinete.email  \
#  0                      3215-5841  dep.alexandreleite@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204503  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                          nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ALEXANDRE ROCHA SANTOS PADILHA  13192679808    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1971-09-14            None           SP  ...          ALEXANDRE PADILHA
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        956                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        956                           9
#
#    ultimoStatus.gabinete.telefone         ultimoStatus.gabinete.email  \
#  0                      3215-5956  dep.alexandrepadilha@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  178833  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                        nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ALEXANDRE AUGUSTUS SERFIOTIS  02440200786    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1975-11-29            None           RJ  ...        ALEXANDRE SERFIOTIS
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        554                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        554                           5
#
#    ultimoStatus.gabinete.telefone           ultimoStatus.gabinete.email  \
#  0                      3215-5554  dep.alexandreserfiotis@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204516  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                              nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  Alexis Joseph Steverlynck Fonteyne  06630660854    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1967-08-19            None           SP  ...            ALEXIS FONTEYNE
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        845                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        845                           8
#
#    ultimoStatus.gabinete.telefone       ultimoStatus.gabinete.email  \
#  0                      3215-5845  dep.alexisfonteyne@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#        id                                                uri  \
#  0  74057  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                  nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ALICE MAZZUCO PORTUGAL  12377392504    F       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1959-05-16            None           BA  ...             ALICE PORTUGAL
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        420                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        420                           4
#
#    ultimoStatus.gabinete.telefone      ultimoStatus.gabinete.email  \
#  0                      3215-5420  dep.aliceportugal@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  178927  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#              nomeCivil          cpf sexo urlWebsite redeSocial dataNascimento  \
#  0  ALIEL MACHADO BARK  06908052923    M       None         []     1989-02-26
#
#    dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0            None           PR  ...              ALIEL MACHADO
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        220                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        220                           2
#
#    ultimoStatus.gabinete.telefone     ultimoStatus.gabinete.email  \
#  0                      3215-5220  dep.alielmachado@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204353  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                         nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ALINE PARANHOS VARONIL GURGEL  51150670215    F       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1980-11-25            None           AP  ...               ALINE GURGEL
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        342                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        342                           3
#
#    ultimoStatus.gabinete.telefone    ultimoStatus.gabinete.email  \
#  0                      3215-5342  dep.alinegurgel@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri       nomeCivil  \
#  0  204400  https://dadosabertos.camara.leg.br/api/v2/depu...  ALINE SLEUTJES
#
#             cpf sexo urlWebsite redeSocial dataNascimento dataFalecimento  \
#  0  00506342913    F       None         []     1979-07-26            None
#
#    ufNascimento  ... ultimoStatus.nomeEleitoral ultimoStatus.gabinete.nome  \
#  0           PR  ...             ALINE SLEUTJES                        550
#
#     ultimoStatus.gabinete.predio ultimoStatus.gabinete.sala  \
#  0                             4                        550
#
#    ultimoStatus.gabinete.andar ultimoStatus.gabinete.telefone  \
#  0                           5                      3215-5550
#
#         ultimoStatus.gabinete.email ultimoStatus.situacao  \
#  0  dep.alinesleutjes@camara.leg.br             Exercício
#
#     ultimoStatus.condicaoEleitoral ultimoStatus.descricaoStatus
#  0                         Titular                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  178937  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                           nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ALTINEU CÔRTES FREITAS COUTINHO  00007487738    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1968-09-13            None           RJ  ...             ALTINEU CÔRTES
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                       None                          None
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                       None                        None
#
#    ultimoStatus.gabinete.telefone ultimoStatus.gabinete.email  \
#  0                           None                        None
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0               Licença                         Titular
#
#    ultimoStatus.descricaoStatus
#  0
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  178881  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                          nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ALUISIO GUIMARAES MENDES FILHO  66746485749    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1961-11-11            None           MG  ...             ALUISIO MENDES
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        931                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        931                           9
#
#    ultimoStatus.gabinete.telefone      ultimoStatus.gabinete.email  \
#  0                      3215-5931  dep.aluisiomendes@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204356  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                       nomeCivil          cpf sexo  \
#  0  AMARO ROCHA NASCIMENTO NETO  06893749767    M
#
#                        urlWebsite                               redeSocial  \
#  0  https://www.amaroneto.com.br/  [amaronetotv, amaronetotv, amaronetotv]
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1976-12-04            None           ES  ...                 AMARO NETO
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        515                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        515                           5
#
#    ultimoStatus.gabinete.telefone  ultimoStatus.gabinete.email  \
#  0                      3215-5515  dep.amaroneto@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  178831  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                  nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ANDRE DOS SANTOS ABDON  31601928220    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1970-11-10            None           PA  ...                ANDRÉ ABDON
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        831                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        831                           8
#
#    ultimoStatus.gabinete.telefone   ultimoStatus.gabinete.email  \
#  0                      3215-5831  dep.andreabdon@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#        id                                                uri  \
#  0  74471  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                             nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ANDRÉ CARLOS ALVES DE PAULA FILHO  34148485468    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1961-07-22            None           PE  ...             ANDRÉ DE PAULA
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        754                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        754                           7
#
#    ultimoStatus.gabinete.telefone     ultimoStatus.gabinete.email  \
#  0                      3215-5754  dep.andredepaula@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204423  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                    nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ANDRÉ FERREIRA RODRIGUES  77050363472    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1972-12-10            None           PE  ...             ANDRÉ FERREIRA
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        450                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        450                           4
#
#    ultimoStatus.gabinete.telefone      ultimoStatus.gabinete.email  \
#  0                      3215-5450  dep.andreferreira@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  133439  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                         nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ANDRÉ PEIXOTO FIGUEIREDO LIMA  25905503320    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1966-11-10            None           CE  ...           ANDRÉ FIGUEIREDO
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        940                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        940                           9
#
#    ultimoStatus.gabinete.telefone        ultimoStatus.gabinete.email  \
#  0                      3215-5940  dep.andrefigueiredo@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  178882  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                       nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ANDRE LUIZ CARVALHO RIBEIRO  03950788301    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1989-08-27            None           MA  ...               ANDRÉ FUFUCA
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        945                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        945                           9
#
#    ultimoStatus.gabinete.telefone    ultimoStatus.gabinete.email  \
#  0                      3215-5945  dep.andrefufuca@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204515  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                     nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ANDRE LUIS GASPAR JANONES  06630008669    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1984-05-05            None           MG  ...              ANDRÉ JANONES
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        580                             3
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        580                        None
#
#    ultimoStatus.gabinete.telefone     ultimoStatus.gabinete.email  \
#  0                      3215-5580  dep.andrejanones@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#        id                                                uri  \
#  0  73696  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                            nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ANGELA REGINA HEINZEN AMIN HELOU  29316715920    F       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1953-12-20            None           SC  ...                ANGELA AMIN
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        252                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        252                           2
#
#    ultimoStatus.gabinete.telefone   ultimoStatus.gabinete.email  \
#  0                      3215-5252  dep.angelaamin@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#        id                                                uri  \
#  0  74212  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                 nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ANÍBAL FERREIRA GOMES  04240952387    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1953-06-07            None           RJ  ...               ANÍBAL GOMES
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                       None                          None
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                       None                        None
#
#    ultimoStatus.gabinete.telefone ultimoStatus.gabinete.email  \
#  0                           None                        None
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Suplência                        Suplente
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  160553  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                                        nomeCivil          cpf sexo urlWebsite  \
#  0  ANTONIO LUIZ PARANHOS RIBEIRO LEITE DE BRITO  51488868549    M       None
#
#    redeSocial dataNascimento dataFalecimento ufNascimento  ...  \
#  0         []     1969-01-17            None           BA  ...
#
#    ultimoStatus.nomeEleitoral ultimoStatus.gabinete.nome  \
#  0              ANTONIO BRITO                        479
#
#     ultimoStatus.gabinete.predio ultimoStatus.gabinete.sala  \
#  0                             3                        479
#
#    ultimoStatus.gabinete.andar ultimoStatus.gabinete.telefone  \
#  0                        None                      3215-5479
#
#        ultimoStatus.gabinete.email ultimoStatus.situacao  \
#  0  dep.antoniobrito@camara.leg.br             Exercício
#
#     ultimoStatus.condicaoEleitoral ultimoStatus.descricaoStatus
#  0                         Titular                         None
#
#  [1 rows x 32 columns],
#        id                                                uri  \
#  0  73433  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                    nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ARLINDO CHIGNALIA JUNIOR  06821146187    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1949-12-24            None           SP  ...          ARLINDO CHINAGLIA
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                          4                             x
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                          4                        None
#
#    ultimoStatus.gabinete.telefone         ultimoStatus.gabinete.email  \
#  0                      3215-5966  dep.arlindochinaglia@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  141391  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                        nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  ARNALDO CALIL PEREIRA JARDIM  04197807856    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1955-05-08            None           SP  ...             ARNALDO JARDIM
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        245                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        245                           2
#
#    ultimoStatus.gabinete.telefone      ultimoStatus.gabinete.email  \
#  0                      3215-5245  dep.arnaldojardim@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204414  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                     nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  JOSE AROLDO SOUZA MARTINS  21074844300    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1961-07-03            None           SP  ...             AROLDO MARTINS
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        437                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        437                           4
#
#    ultimoStatus.gabinete.telefone      ultimoStatus.gabinete.email  \
#  0                      3215-5437  dep.aroldomartins@camara.leg.br
#
# ...
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  179587  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                        nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  VITOR HUGO DE ARAUJO ALMEIDA  07063842706    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1977-05-31            None           BA  ...                 VITOR HUGO
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        803                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        803                           8
#
#    ultimoStatus.gabinete.telefone  ultimoStatus.gabinete.email  \
#  0                      3215-5803  dep.vitorhugo@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri    nomeCivil  \
#  0  178992  https://dadosabertos.camara.leg.br/api/v2/depu...  VITOR LIPPI
#
#             cpf sexo urlWebsite redeSocial dataNascimento dataFalecimento  \
#  0  00168780860    M       None         []     1959-05-18            None
#
#    ufNascimento  ... ultimoStatus.nomeEleitoral ultimoStatus.gabinete.nome  \
#  0           SP  ...                VITOR LIPPI                        823
#
#     ultimoStatus.gabinete.predio ultimoStatus.gabinete.sala  \
#  0                             4                        823
#
#    ultimoStatus.gabinete.andar ultimoStatus.gabinete.telefone  \
#  0                           8                      3215-5823
#
#      ultimoStatus.gabinete.email ultimoStatus.situacao  \
#  0  dep.vitorlippi@camara.leg.br             Exercício
#
#     ultimoStatus.condicaoEleitoral ultimoStatus.descricaoStatus
#  0                         Titular                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204443  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                    nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  WAGNER MONTES DOS SANTOS  26820510730    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1954-07-18      2019-01-26           RJ  ...              WAGNER MONTES
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                       None                          None
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                       None                        None
#
#    ultimoStatus.gabinete.telefone ultimoStatus.gabinete.email  \
#  0                           None                        None
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0              Vacância                          Eleito
#
#                          ultimoStatus.descricaoStatus
#  0  Comunicado de falecimento do Deputado eleito p...
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  160569  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                        nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  WALDENOR ALVES PEREIRA FILHO  10866655549    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1954-03-08            None           BA  ...           WALDENOR PEREIRA
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        954                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        954                           9
#
#    ultimoStatus.gabinete.telefone        ultimoStatus.gabinete.email  \
#  0                      3215-5954  dep.waldenorpereira@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  178952  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  WALTER PEREIRA ALVES  03200380411    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1980-02-27            None           RN  ...               WALTER ALVES
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        435                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        435                           4
#
#    ultimoStatus.gabinete.telefone    ultimoStatus.gabinete.email  \
#  0                      3215-5435  dep.walteralves@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  160518  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                   nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  WELITON FERNANDES PRADO  84719850634    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1975-08-24            None           MG  ...              WELITON PRADO
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        250                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        250                           2
#
#    ultimoStatus.gabinete.telefone     ultimoStatus.gabinete.email  \
#  0                      3215-5250  dep.welitonprado@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#        id                                                uri  \
#  0  74043  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                   nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  JOSÉ WELLINGTON ROBERTO  26254166453    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1959-05-19            None           PB  ...         WELLINGTON ROBERTO
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        514                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        514                           5
#
#    ultimoStatus.gabinete.telefone          ultimoStatus.gabinete.email  \
#  0                      3215-5514  dep.wellingtonroberto@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#        id                                                uri  \
#  0  74044  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  JOSÉ WILSON SANTIAGO  16159977415    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1957-06-10            None           PB  ...            WILSON SANTIAGO
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        534                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        534                           5
#
#    ultimoStatus.gabinete.telefone ultimoStatus.gabinete.email  \
#  0                      3215-5534                        None
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0              Afastado                         Titular
#
#                          ultimoStatus.descricaoStatus
#  0  Afastamento em razão do despacho proferido no ...
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204463  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                                     nomeCivil          cpf sexo urlWebsite  \
#  0  WLADIMIR BARROS ASSED MATHEUS DE OLIVEIRA  10855834730    M       None
#
#    redeSocial dataNascimento dataFalecimento ufNascimento  ...  \
#  0         []     1985-01-13            None           RJ  ...
#
#    ultimoStatus.nomeEleitoral ultimoStatus.gabinete.nome  \
#  0         WLADIMIR GAROTINHO                        274
#
#     ultimoStatus.gabinete.predio ultimoStatus.gabinete.sala  \
#  0                             3                        274
#
#    ultimoStatus.gabinete.andar ultimoStatus.gabinete.telefone  \
#  0                        None                      3215-5274
#
#             ultimoStatus.gabinete.email ultimoStatus.situacao  \
#  0  dep.wladimirgarotinho@camara.leg.br             Exercício
#
#     ultimoStatus.condicaoEleitoral ultimoStatus.descricaoStatus
#  0                         Titular                         None
#
#  [1 rows x 32 columns],
#        id                                                uri  \
#  0  74439  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                 nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  WOLNEY QUEIROZ MACIEL  74989910478    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1972-12-12            None           PE  ...             WOLNEY QUEIROZ
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        936                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        936                           9
#
#    ultimoStatus.gabinete.telefone      ultimoStatus.gabinete.email  \
#  0                      3215-5936  dep.wolneyqueiroz@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  178889  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                    nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  JOSÉ CARLOS NUNES JÚNIOR  10009728368    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1955-05-26            None           MA  ...                  ZÉ CARLOS
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        543                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        543                           5
#
#    ultimoStatus.gabinete.telefone ultimoStatus.gabinete.email  \
#  0                      3215-5543  dep.zecarlos@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204559  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                          nomeCivil          cpf sexo urlWebsite redeSocial  \
#  0  JOSÉ CERQUEIRA DE SANTANA NETO  38247186500    M       None         []
#
#    dataNascimento dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0     1964-03-30            None           BA  ...                    ZÉ NETO
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        585                             3
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        585                        None
#
#    ultimoStatus.gabinete.telefone ultimoStatus.gabinete.email  \
#  0                      3215-5585    dep.zeneto@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  160632  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#             nomeCivil          cpf sexo urlWebsite redeSocial dataNascimento  \
#  0  JOSÉ SILVA SOARES  43422780653    M       None         []     1963-05-11
#
#    dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0            None           MG  ...                   ZÉ SILVA
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        608                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        608                           6
#
#    ultimoStatus.gabinete.telefone ultimoStatus.gabinete.email  \
#  0                      3215-5608   dep.zesilva@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  204517  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                        nomeCivil          cpf sexo urlWebsite  \
#  0  JOSE VITOR DE RESENDE AGUIAR  07284044608    M       None
#
#                 redeSocial dataNascimento dataFalecimento ufNascimento  ...  \
#  0  [zevitorMG, zevitormg]     1984-11-01            None           MG  ...
#
#    ultimoStatus.nomeEleitoral ultimoStatus.gabinete.nome  \
#  0                   ZÉ VITOR                        525
#
#     ultimoStatus.gabinete.predio ultimoStatus.gabinete.sala  \
#  0                             4                        525
#
#    ultimoStatus.gabinete.andar ultimoStatus.gabinete.telefone  \
#  0                           5                      3215-5525
#
#    ultimoStatus.gabinete.email ultimoStatus.situacao  \
#  0   dep.zevitor@camara.leg.br             Exercício
#
#     ultimoStatus.condicaoEleitoral ultimoStatus.descricaoStatus
#  0                         Titular                         None
#
#  [1 rows x 32 columns],
#         id                                                uri  \
#  0  160592  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                                  nomeCivil          cpf sexo urlWebsite  \
#  0  JOSÉ CARLOS BECKER DE OLIVEIRA E SILVA  03098871946    M       None
#
#                                            redeSocial dataNascimento  \
#  0  [http://www.twitter.com/zeca_dirceu, http://ww...     1978-06-21
#
#    dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
#  0            None           PR  ...                ZECA DIRCEU
#
#    ultimoStatus.gabinete.nome  ultimoStatus.gabinete.predio  \
#  0                        613                             4
#
#    ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
#  0                        613                           6
#
#    ultimoStatus.gabinete.telefone   ultimoStatus.gabinete.email  \
#  0                      3215-5613  dep.zecadirceu@camara.leg.br
#
#    ultimoStatus.situacao  ultimoStatus.condicaoEleitoral  \
#  0             Exercício                         Titular
#
#    ultimoStatus.descricaoStatus
#  0                         None
#
#  [1 rows x 32 columns]]

# %%
dicionario_deputados_detalhe = concat(detalhe_deputados, ignore_index=False,sort=True)
dicionario_deputados_detalhe
# Out:
#             cpf dataFalecimento dataNascimento         escolaridade      id  \
# 0   36607606504            None     1965-02-13  Superior Incompleto  204554
# 0   08496582841            None     1966-11-06             Superior  204521
# 0   74287028287            None     1983-09-28             Superior  204379
# 0   80123848504            None     1981-02-02             Superior  204560
# 0   12519851813            None     1969-03-06            Doutorado  204528
# ..          ...             ...            ...                  ...     ...
# 0   10009728368            None     1955-05-26             Superior  178889
# 0   38247186500            None     1964-03-30        Pós-Graduação  204559
# 0   43422780653            None     1963-05-11        Pós-Graduação  160632
# 0   07284044608            None     1984-11-01             Superior  204517
# 0   03098871946            None     1978-06-21             Superior  160592
#
#    municipioNascimento                               nomeCivil  \
# 0             Salvador            JOSE ABILIO SILVA DE SANTANA
# 0            São Paulo                  PAULO SERGIO ABOU ANNI
# 0               Macapá            ACÁCIO DA SILVA FAVACHO NETO
# 0             Salvador             ADOLFO VIANA DE CASTRO NETO
# 0            São Paulo                  ADRIANA MIGUEL VENTURA
# ..                 ...                                     ...
# 0             São Luís                JOSÉ CARLOS NUNES JÚNIOR
# 0     Feira de Santana          JOSÉ CERQUEIRA DE SANTANA NETO
# 0              Iturama                       JOSÉ SILVA SOARES
# 0             Araguari            JOSE VITOR DE RESENDE AGUIAR
# 0             Umuarama  JOSÉ CARLOS BECKER DE OLIVEIRA E SILVA
#
#                                            redeSocial sexo ufNascimento  ...  \
# 0                                                  []    M           BA  ...
# 0   [https://www.facebook.com/abou.anni.7, https:/...    M           SP  ...
# 0   [acaciofavacho, deputadofederalacaciofavacho, ...    M           AP  ...
# 0                                                  []    M           BA  ...
# 0   [adrianasounovo, adrianasounovo, adrianam_vent...    F           SP  ...
# ..                                                ...  ...          ...  ...
# 0                                                  []    M           MA  ...
# 0                                                  []    M           BA  ...
# 0                                                  []    M           MG  ...
# 0                              [zevitorMG, zevitormg]    M           MG  ...
# 0   [http://www.twitter.com/zeca_dirceu, http://ww...    M           PR  ...
#
#    ultimoStatus.nome ultimoStatus.nomeEleitoral ultimoStatus.siglaPartido  \
# 0     ABÍLIO SANTANA             ABÍLIO SANTANA                        PL
# 0          ABOU ANNI                  ABOU ANNI                       PSL
# 0     ACÁCIO FAVACHO             ACÁCIO FAVACHO                      PROS
# 0       ADOLFO VIANA               ADOLFO VIANA                      PSDB
# 0    ADRIANA VENTURA            ADRIANA VENTURA                      NOVO
# ..               ...                        ...                       ...
# 0          ZÉ CARLOS                  ZÉ CARLOS                        PT
# 0            ZÉ NETO                    ZÉ NETO                        PT
# 0           ZÉ SILVA                   ZÉ SILVA             SOLIDARIEDADE
# 0           ZÉ VITOR                   ZÉ VITOR                        PL
# 0        ZECA DIRCEU                ZECA DIRCEU                        PT
#
#    ultimoStatus.siglaUf ultimoStatus.situacao  \
# 0                    BA             Exercício
# 0                    SP             Exercício
# 0                    AP             Exercício
# 0                    BA             Exercício
# 0                    SP             Exercício
# ..                  ...                   ...
# 0                    MA             Exercício
# 0                    BA             Exercício
# 0                    MG             Exercício
# 0                    MG             Exercício
# 0                    PR             Exercício
#
#                                      ultimoStatus.uri  \
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...
# ..                                                ...
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                               ultimoStatus.uriPartido  \
# 0   https://dadosabertos.camara.leg.br/api/v2/part...
# 0   https://dadosabertos.camara.leg.br/api/v2/part...
# 0   https://dadosabertos.camara.leg.br/api/v2/part...
# 0   https://dadosabertos.camara.leg.br/api/v2/part...
# 0   https://dadosabertos.camara.leg.br/api/v2/part...
# ..                                                ...
# 0   https://dadosabertos.camara.leg.br/api/v2/part...
# 0   https://dadosabertos.camara.leg.br/api/v2/part...
# 0   https://dadosabertos.camara.leg.br/api/v2/part...
# 0   https://dadosabertos.camara.leg.br/api/v2/part...
# 0   https://dadosabertos.camara.leg.br/api/v2/part...
#
#                                  ultimoStatus.urlFoto  \
# 0   https://www.camara.leg.br/internet/deputado/ba...
# 0   https://www.camara.leg.br/internet/deputado/ba...
# 0   https://www.camara.leg.br/internet/deputado/ba...
# 0   https://www.camara.leg.br/internet/deputado/ba...
# 0   https://www.camara.leg.br/internet/deputado/ba...
# ..                                                ...
# 0   https://www.camara.leg.br/internet/deputado/ba...
# 0   https://www.camara.leg.br/internet/deputado/ba...
# 0   https://www.camara.leg.br/internet/deputado/ba...
# 0   https://www.camara.leg.br/internet/deputado/ba...
# 0   https://www.camara.leg.br/internet/deputado/ba...
#
#                                                   uri urlWebsite
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...       None
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...       None
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...       None
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...       None
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...       None
# ..                                                ...        ...
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...       None
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...       None
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...       None
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...       None
# 0   https://dadosabertos.camara.leg.br/api/v2/depu...       None
#
# [545 rows x 32 columns]

# %%
print(engine.table_names())
# Out:
# ['detalhe_deputados']

# %%
#GRAVA OS DETALHES DOS DEPUTADOS
"""
table_name = 'deputados_detalhes'
dicionario_deputados_detalhe.to_sql(table_name, con, if_exists='append',)
print(engine.table_names())
"""
# Out:
# ['deputados_detalhes']

# %%
exit()

# %%
#df3.nome.find('Câmera')
df3.sort_values(["data_periodo", "nome"], axis=0, 
                 ascending=True, inplace=True) 
df3.loc[df3['nome'].str.contains('SILAS CÂMARA')].head(2)
# Out:
#         id                                                uri          nome  \
# 494  74356  https://dadosabertos.camara.leg.br/api/v2/depu...  SILAS CÂMARA
# 494  74356  https://dadosabertos.camara.leg.br/api/v2/depu...  SILAS CÂMARA
#
#      siglaPartido                                         uriPartido siglaUf  \
# 494  REPUBLICANOS  https://dadosabertos.camara.leg.br/api/v2/part...      AM
# 494  REPUBLICANOS  https://dadosabertos.camara.leg.br/api/v2/part...      AM
#
#      idLegislatura                                            urlFoto  \
# 494             56  https://www.camara.leg.br/internet/deputado/ba...
# 494             56  https://www.camara.leg.br/internet/deputado/ba...
#
#                              email data_periodo
# 494  dep.silascamara@camara.leg.br   18-06-01@0
# 494  dep.silascamara@camara.leg.br   18-07-01@0
